# %%
from nilearn import plotting
from nilearn import image

# %%
#https://stackoverflow.com/questions/18425225/getting-the-name-of-a-variable-as-a-string
import inspect

def retrieve_name(var):
        """
        Gets the name of var. Does it from the out most frame inner-wards.
        :param var: variable to get name from.
        :return: string
        """
        for fi in reversed(inspect.stack()):
            names = [var_name for var_name, var_val in fi.frame.f_locals.items() if var_val is var]
            if len(names) > 0:
                return names[0]

# %%
BA6_Left = "C:/Users/Lynn Verty/Documents/ROIs_BHS2020/BA6_left.nii"
BA6_Right = "C:/Users/Lynn Verty/Documents/ROIs_BHS2020/BA6_right.nii"
ROI = [BA6_Right, BA6_Left]

# %%
for x in ROI:
        plotting.plot_roi(x,cmap='winter', title = retrieve_name(x), draw_cross= False,black_bg=True)#, output_file=retrieve_name(x))

# %%
plotting.plot_roi(BA6_Left,cmap='winter', title = '', draw_cross= False,black_bg=True, display_mode='xz')#, output_file=retrieve_name(x))

# %%
plotting.plot_roi(BA6_Right,cmap='winter', title = '', draw_cross= False,black_bg=True, display_mode='xz')#, output_file=retrieve_name(x))
